# %%
import pandas as pd
df = pd.read_csv(r"D:\gigggs\10Academy\week2-10academy\data\clean\cleaned_reviews.csv", encoding="cp1252", errors="replace")
df.to_csv(r"D:\gigggs\10Academy\week2-10academy\data\clean\cleaned_reviews_utf8.csv", index=False, encoding="utf-8")

# %%
import pandas as pd

df = pd.read_csv("D:/gigggs/10Academy/week2-10academy/data/clean/cleaned_reviews_utf8.csv", encoding="utf-8")

print(df.shape)
print(df.columns)

print(df.head())
# Out:
# (773, 11)
# Index(['review_id', 'review_text', 'rating', 'review_date', 'user_name',
#        'thumbs_up', 'reply_content', 'bank_code', 'bank_name', 'app_id',
#        'source'],
#       dtype='object')
#                               review_id                       review_text  \
# 0  cb37b096-e071-4f0f-a8fd-067b7d71706d               CBE á‹­áˆˆá‹«áˆ�á�¢
# 1  70f504ff-daed-40d9-9c89-cc49a95ef659               it's special for me
# 2  28f229b5-0026-41b9-a1eb-b76e74736f63            Make it user friendly.
# 3  68d8daea-db47-4e23-a692-755173dea983  maaliif daddafee install gaafata
# 4  ee0dbb0e-4eb0-47b5-9874-c37877493f99                          good app
#
#    rating          review_date         user_name  thumbs_up reply_content  \
# 0       5  2025-11-29 17:22:32     Kamil Tesfaye          0           NaN
# 1       5  2025-11-29 15:54:14        Abde Semed          0           NaN
# 2       2  2025-11-29 08:17:45  TOMIZ Creativity          0           NaN
# ...

# %%
import pandas as pd
import csv

df = pd.read_csv(
    r"D:\gigggs\10Academy\week2-10academy\data\clean\cleaned_reviews.csv",
    encoding="cp1252",
    encoding_errors="replace"  
)
df = df[['bank_name', 'review_text', 'rating', 'review_date']]
df.to_csv(
    r"D:\gigggs\10Academy\week2-10academy\data\clean\cleaned_reviews_postgres.csv",
    index=False,
    encoding="utf-8",
    quoting=csv.QUOTE_ALL
)
